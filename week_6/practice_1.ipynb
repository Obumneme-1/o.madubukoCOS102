# %%
# Practice | Cell 1 - Your First Class

class SST:
    prog1 = "Computer Science" # class variable

    def __init__(self, name):
        self.name = name # instance variable
    def speak(self):
        print('\nMy name is', self.name)
        print('I study', SST.prog1)

stud1 = SST(input('Enter student 1 name: '))
stud2 = SST(input('Enter student 2 name: '))

stud1.speak()
stud2.speak()
# Out:
# Enter student 1 name:  obum
# Enter student 2 name:  raji
# My name is obum
# I study Computer Science
#
# My name is raji
# I study Computer Science

# %%
class Addition:
    def __init__(self, f, s):
        self.first =f
        self.second = s
        self.answer = None

    def calculate(self):
        self.answer = self.first + self.second

    def display(self):
        print('\nFirst:', self.first)
        print('Second:', self.second)
        print('\nsum:', self.answer)


num1 = int(input('Enter first number: '))
num2 = int(input('Enter second number: '))

obj = Addition(num1, num2)
obj.calculate()
obj.display()
# Out:
# Enter first number:  10
# Enter second number:  20
# First: 10
# Second: 20
#
# sum: 30
