# %%
# Data for Girls
girls_names = ["Evelyn", "Jessica", "Somto", "Edith", "Liza", "Madonna", "Waje", "Tola", "Aisha", "Latifa"]
girls_age = [17, 16, 17, 18, 16, 18, 17, 20, 19, 17]
girls_height = [5.5, 6.0, 5.4, 5.9, 5.6, 5.5, 6.1, 6.0, 5.7, 5.5]
girls_scores = [80, 85, 70, 60, 76, 66, 87, 95, 50, 49]

# Data for Boys
boys_names = ["Chinedu", "Liam", "Wale", "Gbenga", "Abiola", "Kola", "Kunle", "George", "Thomas", "Wesley"]
boys_age = [19, 16, 18, 17, 20, 19, 16, 18, 17, 19]
boys_height = [5.7, 5.9, 5.8, 6.1, 5.9, 5.5, 6.1, 5.4, 5.8, 5.7]
boys_scores = [74, 87, 75, 68, 66, 78, 87, 98, 54, 60]

# Function to display the table
def display_table():
    # Header
    print(f"{'NAME':<12} | {'AGE':<5} | {'HEIGHT':<7} | {'SCORE':<5}")
    print("-" * 45)

    # Print Girls
    for i in range(len(girls_names)):
        print(f"{girls_names[i]:<12} | {girls_age[i]:<5} | {girls_height[i]:<7} | {girls_scores[i]:<5}")

    # Print Boys
    for i in range(len(boys_names)):
        print(f"{boys_names[i]:<12} | {boys_age[i]:<5} | {boys_height[i]:<7} | {boys_scores[i]:<5}")

# Run the program
if __name__ == "__main__":
    display_table()
# Out:
# NAME         | AGE   | HEIGHT  | SCORE
# ---------------------------------------------
# Evelyn       | 17    | 5.5     | 80
# Jessica      | 16    | 6.0     | 85
# Somto        | 17    | 5.4     | 70
# Edith        | 18    | 5.9     | 60
# Liza         | 16    | 5.6     | 76
# Madonna      | 18    | 5.5     | 66
# Waje         | 17    | 6.1     | 87
# Tola         | 20    | 6.0     | 95
# Aisha        | 19    | 5.7     | 50
# Latifa       | 17    | 5.5     | 49
# Chinedu      | 19    | 5.7     | 74
# Liam         | 16    | 5.9     | 87
# Wale         | 18    | 5.8     | 75
# Gbenga       | 17    | 6.1     | 68
# Abiola       | 20    | 5.9     | 66
# Kola         | 19    | 5.5     | 78
# Kunle        | 16    | 6.1     | 87
# George       | 18    | 5.4     | 98
# Thomas       | 17    | 5.8     | 54
# Wesley       | 19    | 5.7     | 60

# %% [markdown]
# START
#   CREATE lists for girls_names, girls_age, girls_height, girls_scores
#   CREATE lists for boys_names, boys_age, boys_height, boys_scores
#
#   PRINT table header: "Name | Age | Height | Score"
#   PRINT separator line
#
#   FOR each index from 0 to 9:
#     PRINT girls_names[index], girls_age[index], girls_height[index], girls_scores[index]
#
#   FOR each index from 0 to 9:
#     PRINT boys_names[index], boys_age[index], boys_height[index], boys_scores[index]
# END
